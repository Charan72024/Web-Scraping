# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

url = "https://www.espncricinfo.com/records/most-runs-in-career-282827"
response = requests.get(url)
html_content = response.text

soup = BeautifulSoup(html_content, "html.parser")

table = soup.find("table")

data = []
rows = table.find_all("tr")
for row in rows:
    cells = row.find_all("td")
    row_data = [cell.text.strip() for cell in cells]
    data.append(row_data)

df = pd.DataFrame(data)  # Create a DataFrame

# %%
df
# Out:
#                          0          1    2     3   4     5     6      7   \
# 0                    Player       Span  Mat  Inns  NO  Runs    HS    Ave
# 1           RG Sharma (IND)  2007-2024  157   149  19  4165  121*  32.03
# 2          Babar Azam (PAK)  2016-2024  123   116  15  4145   122  41.03
# 3             V Kohli (IND)  2010-2024  123   115  31  4103  122*  48.84
# 4         PR Stirling (IRE)  2009-2024  145   144  11  3601  115*  27.07
# ..                      ...        ...  ...   ...  ..   ...   ...    ...
# 146       KIC Asalanka (SL)  2021-2024   47    47   5  1061   80*  25.26
# 147         V Aravind (UAE)  2020-2024   48    43   5  1052   97*  27.68
# 148       W Madhevere (ZIM)  2020-2023   60    57   7  1047   73*  20.94
# 149     Anshuman Rath (HKG)  2015-2024   46    45   5  1046   72*  26.15
# 150  Zubaidi Zulkifle (MAS)  2019-2024   52    51   2  1045    96  21.32
#
#        8       9    10  11  12   13   14
# 0      BF      SR  100  50   0   4s   6s
# 1    2959  140.75    5  31  12  375  203
# 2    3211  129.08    3  36   6  440   72
# 3    2988  137.31    1  37   7  363  121
# 4    2675  134.61    1  23  13  418  128
# ..    ...     ...  ...  ..  ..  ...  ...
# 146   837  126.76    0   5   4   69   52
# 147   936  112.39    0   6   4  105   23
# 148   880  118.97    0   7   5  119   14
# 149   942  111.04    0   4   1  110   13
# 150   702  148.86    0   3   7  106   51
#
# [151 rows x 15 columns]

# %%
df = pd.DataFrame(data[1:], columns=data[0])

# %%
df
# Out:
#                      Player       Span  Mat Inns  NO  Runs    HS    Ave    BF  \
# 0           RG Sharma (IND)  2007-2024  157  149  19  4165  121*  32.03  2959
# 1          Babar Azam (PAK)  2016-2024  123  116  15  4145   122  41.03  3211
# 2             V Kohli (IND)  2010-2024  123  115  31  4103  122*  48.84  2988
# 3         PR Stirling (IRE)  2009-2024  145  144  11  3601  115*  27.07  2675
# 4           MJ Guptill (NZ)  2009-2022  122  118   7  3531   105  31.81  2602
# ..                      ...        ...  ...  ...  ..   ...   ...    ...   ...
# 145       KIC Asalanka (SL)  2021-2024   47   47   5  1061   80*  25.26   837
# 146         V Aravind (UAE)  2020-2024   48   43   5  1052   97*  27.68   936
# 147       W Madhevere (ZIM)  2020-2023   60   57   7  1047   73*  20.94   880
# 148     Anshuman Rath (HKG)  2015-2024   46   45   5  1046   72*  26.15   942
# 149  Zubaidi Zulkifle (MAS)  2019-2024   52   51   2  1045    96  21.32   702
#
#          SR 100  50   0   4s   6s
# 0    140.75   5  31  12  375  203
# 1    129.08   3  36   6  440   72
# 2    137.31   1  37   7  363  121
# 3    134.61   1  23  13  418  128
# 4    135.70   2  20   3  309  173
# ..      ...  ..  ..  ..  ...  ...
# 145  126.76   0   5   4   69   52
# 146  112.39   0   6   4  105   23
# 147  118.97   0   7   5  119   14
# 148  111.04   0   4   1  110   13
# 149  148.86   0   3   7  106   51
#
# [150 rows x 15 columns]

# %%
df.to_csv('Batting_Most_runs.csv', index=False)
